# %% [markdown]
# # Users with hybrid energy carrier, but fixed time range.

# %% [markdown]
# # 10% of users allowed their appliances to operate on hybrid mode, 90% of users operate on standard mode and 100% users with fixed time range.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
SUB = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉")
co2 = "CO2".translate(SUB)

# %%
x = np.arange(1, 97, 1)
y_CO2_electricity = [0.487, 0.485, 0.480, 0.478, 0.478, 0.475, 0.472, 0.470, 0.470, 0.468, 0.465, 0.460, 0.457,0.456,
        0.451, 0.452, 0.452, 0.450, 0.448, 0.443, 0.438, 0.438, 0.440, 0.440, 0.437, 0.435, 0.435, 0.436,
        0.437, 0.437, 0.438, 0.438, 0.438, 0.441, 0.443, 0.449, 0.455, 0.460, 0.464, 0.467, 0.481, 0.489, 0.495, 0.497,
        0.504, 0.509, 0.514, 0.520, 0.536, 0.549, 0.554, 0.559, 0.565, 0.569, 0.571, 0.571, 0.558, 0.562, 0.570, 0.574,
        0.567, 0.572, 0.572, 0.568, 0.567, 0.563, 0.558, 0.555, 0.554, 0.552, 0.551, 0.549, 0.542, 0.540, 0.542, 0.543,
        0.544, 0.547, 0.576, 0.549, 0.552, 0.557, 0.557, 0.560, 0.563, 0.563, 0.563, 0.567, 0.568, 0.566, 0.561,
        0.550, 0.548, 0.541, 0.532,0.524]

# %%
y_electricity10 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1785,14595,7185,1785,757.5,3285,1410,13657.5,14685,14685,10957.5,9960,7530,157.5,1185,1035,7.5,1035,1035,7.5,1635,15285,607.5,1635,1635,14257.5,3120,3120,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5
]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity10, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption while 10% user possess flexible energy carrier but not time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 20% of users allowed their appliances to operate on hybrid mode, 80% of users operate on standard mode and 100% users with fixed time range.

# %%
y_electricity20 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1785,14182.5,6585,1785,757.5,3285,1410,12307.5,13335,13335,9907.5,9135,6975,307.5,1335,1035,7.5,1035,1035,7.5,1635,14535,607.5,1635,1635,13507.5,2955,2055,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity20, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption while 20% user possess flexible energy carrier but not time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 30% of users allowed their appliances to operate on hybrid mode, 70% of users operate on standard mode and 100% users with fixed time range.

# %%
y_electricity30 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1785,13770,5985,1785,757.5,3285,1410,10957.5,11985,11985,8857.5,8310,6420,457.5,1485,1035,7.5,1035,1035,7.5,1635,13785,607.5,1635,1635,12757.5,2790,2002.5,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity30, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption while 10% user possess flexible energy carrier but not time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 40% of users allowed their appliances to operate on hybrid mode, 60% of users operate on standard mode and 100% users with fixed time range.

# %%
y_electricity40 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1785,13357.5,5385,1785,757.5,3285,1410,9607.5,10635,10635,7807.5,7485,5865,607.5,1635,1035,7.5,1035,1035,7.5,1635,13035,607.5,1635,1635,12007.5,2625,1950,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity40, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption while 40% user possess flexible energy carrier but not time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 50% of users allowed their appliances to operate on hybrid mode, 50% of users operate on standard mode and 100% users with fixed time range.

# %%
y_electricity50 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1785,12945,4785,1785,757.5,3285,1410,8257.5,9285,9285,6757.5,6660,5310,757.5,1785,1035,7.5,1035,1035,7.5,1635,12285,607.5,1635,1635,11257.5,2460,1897.5,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5
]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity50, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption while 50% user possess flexible energy carrier but not time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 60% of users allowed their appliances to operate on hybrid mode, 40% of users operate on standard mode and 100% users with fixed time range.

# %%
y_electricity60 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1785,12532.5,4185,1785,757.5,3285,1410,6907.5,7935,7935,5707.5,5835,4755,907.5,1935,1035,7.5,1035,1035,7.5,1635,11535,607.5,1635,1635,10507.5,2295,1845,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity60, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption while 60% user possess flexible energy carrier but not time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 70% of users allowed their appliances to operate on hybrid mode, 30% of users operate on standard mode and 100% users with fixed time range.

# %%
y_electricity70 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1785,12120,3585,1785,757.5,3285,1410,5557.5,6585,6585,4657.5,5010,4200,1057.5,2085,1035,7.5,1035,1035,7.5,1635,10785,607.5,1635,1635,9757.5,2130,1792.5,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity70, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption while 70% user possess flexible energy carrier but not time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 80% of users allowed their appliances to operate on hybrid mode, 20% of users operate on standard mode and 100% users with fixed time range.

# %%
y_electricity80 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1785,11707.5,2985,1785,757.5,3285,1410,4207.5,5235,5235,3607.5,4185,3645,1207.5,2235,1035,7.5,1035,1035,7.5,1635,10035,607.5,1635,1635,9007.5,1965,1740,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5
]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity80, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption while 80% user possess flexible energy carrier but not time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 90% of users allowed their appliances to operate on hybrid mode, 10% of users operate on standard mode and 100% users with fixed time range.

# %%
y_electricity90 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1785,11295,2385,1785,757.5,3285,1410,2857.5,3885,3885,2557.5,3360,3090,1357.5,2385,1035,7.5,1035,1035,7.5,1635,9285,607.5,1095,1635,8257.5,1800,1687.5,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity90, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption while 90% user possess flexible energy carrier but not time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 100% of users allowed their appliances to operate on hybrid mode and 100% users with fixed time range.

# %%
y_electricity100 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1785,10882.5,1785,1785,757.5,3285,1410,1507.5,2535,2535,1507.5,2535,2535,1507.5,2535,1035,7.5,1035,1035,7.5,1635,8535,607.5,1635,1635,7507.5,1635,1635,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity10, color = 'b', label = 'Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15AM Hours) to 96(6:00AM Hours) each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption energy in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('g'+co2+'/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption of thirty users with flexible energy carrier, but fixed time range', va='baseline', fontsize='15')
fig.tight_layout()
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.text(0.3, 0.3, "OFF PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
fig.text(0.6, 0.95, "ON PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
fig.text(0.35, 0.7,"MID PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
plt.show()
