# %% [markdown]
# # Load pattern during more renwebale energy production, where users allowed their appliance to operate on hybrid mode and mixed time range

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
SUB = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉")
co2 = "CO2".translate(SUB)

# %%
x = np.arange(1, 97, 1)

y_electricity = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,757.5,11910,1785,757.5,1785,3285,382.5,2535,2535,1507.5,2535,2535,1507.5,2535,2535,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1635,7507.5,1635,1635,607.5,8535,1635,607.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

y_CO2_electricity = [0.289, 0.294, 0.302, 0.308, 0.32, 0.33, 0.337, 0.342, 0.351, 0.355, 0.358, 0.361, 0.364, 0.366, 0.368, 0.371, 0.372, 0.372, 0.368, 0.376, 0.376, 0.386, 0.388, 0.397, 0.409, 0.419, 0.43, 0.435, 0.443, 0.445, 0.453, 0.462, 0.473, 0.478, 0.482, 0.488, 0.489, 0.475, 0.47, 0.466, 0.466, 0.477, 0.465, 0.465, 0.479, 0.479, 0.467, 0.481, 0.468, 0.483, 0.483, 0.479, 0.487, 0.477, 0.482, 0.489, 0.479, 0.479, 0.478, 0.475, 0.472, 0.467, 0.464, 0.457, 0.456, 0.45, 0.444, 0.433, 0.429, 0.428, 0.425, 0.423, 0.423, 0.422, 0.424, 0.425, 0.427, 0.428, 0.428, 0.427, 0.428, 0.431, 0.432, 0.434, 0.436, 0.438, 0.439, 0.441, 0.442, 0.443, 0.445, 0.445, 0.447, 0.452, 0.456, 0.46]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity, color = 'b', label = 'Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15AM Hours) to 96(6:00AM Hours) each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('g'+co2+'/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption of thirty users during large amount of renewable energy production', va='baseline', fontsize='15')
fig.tight_layout()
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.text(0.1, 0.3, "OFF PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
fig.text(0.4, 0.95, "ON PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
fig.text(0.2, 0.6,"MID PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
plt.show()
