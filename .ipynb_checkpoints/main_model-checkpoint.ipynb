# %%
from gurobipy import *
# %run main_data.ipynb

# %% [markdown]
# # create a new model.

# %%
m = Model("scheduling")
# Out:
# Academic license - for non-commercial use only

# %% [markdown]
# # Creating a Binary Variables

# %%
vars_tup = [(t, u, app, task) for t in time_slots for u in users for app in appliances for task in task_appliances[app]]

# %% [markdown]
# Creating the Binary varibale indicates whether task $j$ of appliance $i$ of user $u$ at time slot $t$ processed by only electricity or not; 1 = processed, 0 = not processed denoted by $y_{t, u, i, j}$.

# %%
x = m.addVars(vars_tup, vtype = GRB.BINARY, name = 'x')

# %% [markdown]
# Creating the binary varibale indicated whether task $j$ of appliances $i$ of user $u$ at time slot $t$ processed by both electricity and hotwater or not; 1 = processed, 0 = not processed denoted by $y_{t, u, i, j}$.

# %%
y = m.addVars(vars_tup, vtype = GRB.BINARY, name = 'y')

# %% [markdown]
# Creating the binary varibale indicated whether task $j$ of appliances $i$ of user $u$ at time slot $t$ processed by natural gas or not; 1 = processed, 0 = not processed denoted by $z_{t, u, i, j}$.

# %%
z = m.addVars(vars_tup, vtype = GRB.BINARY, name = 'z')

# %% [markdown]
# Creating a binary variable indicated the On and Off status of the Boiler at time slot t; 1 = On or 0 = off denoted by $s_t^{Boiler}$.

# %%
s = m.addVars(time_slots, vtype = GRB.BINARY, name = 's')

# %% [markdown]
# # Creating the Variables for the Model

# %% [markdown]
# Amount of hotwater available in the storage tank at time slot $t$ denoted by $H_{t}^{available}$(WH).

# %%
available_hotwater_storagetank = m.addVars(time_slots, lb = 0, ub = 31719 , vtype = GRB.CONTINUOUS, name = 'available_hotwater_storagetank')

# %% [markdown]
# Thermal output of the Boiler at time slot $t$ denoted by $T_t^{Boiler}$(wh).

# %%
boiler_produced_thermal = m.addVars(time_slots, lb = 0, ub = 21250 , vtype = GRB.CONTINUOUS, name = "boiler_produced_thermal")

# %% [markdown]
# Hotwater Produced by Boiler at time slot $t$ denoted by $H_t^{Boiler}$(wh).

# %%
boiler_produced_hotwater = m.addVars(time_slots, lb =0, ub = 125615 ,  vtype = GRB.CONTINUOUS, name = "boiler_produced_hotwater")

# %% [markdown]
# Amount of gas required by Boiler at time slot $t$ denoted by $G_t^{Boiler}$ ($Wh$).

# %%
boiler_required_gas = m.addVars(time_slots, lb = 0, ub = 19125, vtype = GRB.CONTINUOUS, name = "boiler_required_gas")

# %%
m.update()

# %% [markdown]
# # Set the Objective Function

# %% [markdown]
# Objective is to minimize the CO2 emission from the group of users who has same set of the household appliances.

# %% [markdown]
# \begin{multline} \label{eq1}
# minimize \sum_{t=1}^{96}\sum_{u=1}^{50}\sum_{i=1}^N\sum_{j=1}^{n_i} C_{t}^{electricity}  E_{u,i,j}^{high} x_{t,u,i,j}+ [C_{t}^{electricity}  E_{u,i,j}^{low}
# +C_{t}^{gas}  H_{u,i,j}] y_{t,u,i,j}+ C_{t}^{gas}[ G_{u,i,j} z_{t,u,i,j} + G_{t}^{Boiler}]
# \end{multline}

# %%
obj = quicksum(co2_factor_electricity[t] *  float(electricity_high_req[u, app, task]) * x[t, u, app, task] +
               co2_factor_electricity[t] * float(electricity_low_req[u, app, task]) * y[t, u, app, task]  + co2_factor_gas * float(hotwater_req[u, app, task]) *  y[t, u, app, task] +
               co2_factor_gas * float(gas_req[u, app, task]) * z[t, u , app, task] + co2_factor_gas * boiler_required_gas[t]
                 for t in time_slots for u in users for app in appliances for task in task_appliances[app])

# %%
m.setObjective(obj, GRB.MINIMIZE)

# %% [markdown]
# Update the Model.

# %%
m.update()

# %% [markdown]
# # Create the Constraints for the model

# %% [markdown]
# Subject to Constraints

# %% [markdown]
# The appliances can to use electricity or both electricity and hotwater or Gas energy carrier at a time to process its task.
#
# $x_{t,u,i,j}+ y_{t,u,i,j}+ z_{t,u,i,j}  \leq 1$ $\forall t, u, i, j, \{w_{t, u, i, j}, x_{t,u,i,j}, y_{t,u,i,j}, z_{t,u,i,j}\} \in \{0,1\}$

# %%
energy_carrier = m.addConstrs((x[t, u, app, task] + y[t, u, app, task] + z[t, u, app, task] <= 1
             for t in time_slots for u in users for app in appliances for task in task_appliances[app]),
                              name = "energy_carrier")

# %% [markdown]
# The amount of electricity demand at any time slot should not exceed the $PEAK$ electricity threshold of the distribution grid.
#
# \begin{multline} \label{eq5}
# \sum_{u=1}^{50}\sum_{i=1}^{N}\sum_{j=1}^{n_i} E_{u,i,j}^{high} * x_{t,u,i,j} +E_{u, i, j}^{low} * y_{t, u, i, j} \leq PEAK \qquad \forall t , x_{t,u,i,j}, y_{t, u, i, j} \in \{0,1\}
# \end{multline}

# %%
peak_constraint = m.addConstrs((quicksum(electricity_high_req[u, app, task] * x[t, u, app, task] + electricity_low_req[u, app, task] * y[t, u, app, task] 
                                         for u in users for app in appliances for task in task_appliances[app]) <= PEAK for t in time_slots),
                              name = "peak_constraint")

# %% [markdown]
# The amount of hot water demand by all tasks of the appliances at any time slot should not exceed the capacity of the hot water storage tank.
# \begin{multline} \label{eq4}
# \sum_{i=1}^N \sum_{j=1}^{n_i} H_{u,i,j} * y_{tu,i,j} \leq C_{ST} \qquad \forall t, u ,  y_{tu,i,j} \in \{0,1\}
# \end{multline}

# %%
hotwater_demand_constarint = m.addConstrs((quicksum(hotwater_req[u, app, task] * y[t, u, app, task] for app in appliances for task in task_appliances[app]) <= tank_capacity  
                                          for t in time_slots for u in users), name = "hotwater_demand_constarint")

# %% [markdown]
# The amount of gas required by Boiler to produce thermal power measured in Wh.
#
# \begin{equation} \label{eq8}
# G_{t}^{Boiler} =  \frac {T_{t}^{Boiler}}{\eta_{th}}
# \end{equation}

# %%
boiler_gas = m.addConstrs((boiler_required_gas[t] == (boiler_produced_thermal[t]/boiler_efficiecny) for t in time_slots), 
            name = "boiler_gas")

# %% [markdown]
# Convert the thermal power produced by the boiler into the hotwater. For instance, the water temperature rise from 0 degree to 65 degree. Hence the $\textit{Temp}$ is 65 degree. Where 4 being a 1/4th of hour and 3412 being a given constant. This formula tells the amount of hot water produced by thermal energy of the boiler in 15 minute.
#
# \begin{equation} \label{eq8a}
# H_{t}^{Boiler} = \frac {T_{t}^{Boiler} * 3412 } {2.22 * 65 * 4}
# \end{equation}

# %%
boiler_hotwater = m.addConstrs((boiler_produced_hotwater[t] == (boiler_produced_thermal[t] * 3412)/(2.22 * 65 * 4) 
                                for t in time_slots), name = "boiler_hotwater")

# %% [markdown]
# The amount of thermal energy produced by boiler should not exceeds its maximum thermal output at time slot t.
#
# $ 0<=T_{t, u}^{Boiler} <= s_{t}^{Boiler}. T_{max}^{Boiler}$

# %%
Boiler_capacity = m.addConstrs((0 <= boiler_produced_thermal[t] <= s[t] * boiler_thermal_max  for t in time_slots), 
                               name = "Boiler_capacity")

# %%
boiler_hotwater_capacity = m.addConstrs((0 <= boiler_produced_hotwater[t] <= boiler_howater_max  for t in time_slots), name = "Boiler_hotwater_capacity")

# %% [markdown]
# The amount of hot water available in the storage tank at time slot k is equal to the amount stored at k-1 plus the hot water produced by the boiler minus hot water consumed by the appliances.
#
# \begin{equation} \label{10a}
# H_{t}^{a} = H_{t-1}^{a} + H_{t}^{Boiler} - \sum_{i=1}^{N} \sum_{j=1}^{n_i} H_{u,i,j} * y_{t,u,i,j}\\ \forall u, t= {2, 3, .. }
# \end{equation}

# %%
available_hotwater = m.addConstrs((available_hotwater_storagetank[time_slots[t_index]] == 
                                   available_hotwater_storagetank[time_slots[t_index-1]] + boiler_produced_hotwater[time_slots[t_index]] -
                                   quicksum(hotwater_req[u, app, task] * y[time_slots[t_index], u, app, task]  for app in appliances for task in task_appliances[app])
                                  for t_index, t in enumerate(time_slots) for u in users if t_index != 0))

# %% [markdown]
# Hot water storage tank capacity has to be maintained at any time slot.
#
# \begin{equation} \label{eq10b}
# 0 \leq H_{t}^a \leq C_{ST}  \qquad \forall t = \{1,2,. . .96\}
# \end{equation}

# %%
available_hotwater_capacity = m.addConstrs((0 <= available_hotwater_storagetank[t] <= tank_capacity 
                                            for t in time_slots), name = "available_hotwater_capacity")

# %% [markdown]
# The task of the appliances should not be performed outside the user-specified time window.
#
# \begin{equation} \label{eq12}
# \sum_{t\in m-[t_{st,i}, t_{end,i}]} x_{t,u,i,j} + y_{t,u,i,j} + z_{t,u,i,j} = 0 \quad \forall i,j,u
# \end{equation}

# %%
not_perform_task = m.addConstrs((quicksum(x[time_slots[t_index], u, app, task] + y[time_slots[t_index], u, app, task]+ z[time_slots[t_index], u, app, task] 
                                          for t_index, t in enumerate(time_slots) if t_index not in range(starting_time_slot[app]-1, ending_time_slot[app]) and t_index != len(time_slots)) 
                                          == 0 for u in users for app in appliances for task in task_appliances[app]), 
                                          name = "not_perform_task")

# %% [markdown]
# The task of the appliances are not interupptible it means it can't be stop untill it finishes it's task.

# %% [markdown]
# $x_{t, u, i, j} = x_{t-1, u, i, j-1}$
#
# $y_{t, u, i, j} = y_{t-1, u, i, j-1}$
#
# $z_{t, u, i, j} = z_{t-1, u, i, j-1}$ $\forall u, i, j = 2, 3, ... , t = 2,3,4 . . .96$

# %%
appliance_task_contionously1 = m.addConstrs((x[time_slots[t_index], u, app, task_appliances[app][task_index]] ==
                                            x[time_slots[t_index-1], u, app, task_appliances[app][task_index-1]]
                                            for t_index, t in enumerate(time_slots) for u in users for app in appliances for task_index, task in enumerate(task_appliances[app])
                                            if t_index != 0 and task_index !=0), name = "appliance_task_contionously1")
                      
appliance_task_contionously2 = m.addConstrs((y[time_slots[t_index], u, app, task_appliances[app][task_index]] ==
                                            y[time_slots[t_index-1], u, app, task_appliances[app][task_index-1]] 
                                            for t_index, t in enumerate(time_slots) for u in users for app in appliances for task_index, task in enumerate(task_appliances[app])
                                            if t_index != 0 and task_index !=0), name = "appliance_task_contionously2")

                      
appliance_task_contionously3 = m.addConstrs((z[time_slots[t_index], u, app, task_appliances[app][task_index]] ==
                                            z[time_slots[t_index-1], u, app, task_appliances[app][task_index-1]] 
                                            for t_index, t in enumerate(time_slots) for u in users for app in appliances for task_index, task in enumerate(task_appliances[app])
                                            if t_index != 0 and task_index !=0), name = "appliance_task_contionously3")

# %% [markdown]
# The tasks of the refrigerator has to be sequential.
#
# The refrigerator should starts from first task at the first time slot.
#
# $x_{t_0, u, i, j_{0}} = 1 $
#
# ${t_0}$ = first time slot of refrigerator
# $\forall u $ and i = refrigerator, $j_{0}$ = 1st task of refrigerator

# %%
starts_with_1st_task = m.addConstrs((x[time_slots[t_index], u, app, task] == 1 for t_index, t in enumerate(time_slots) for u in users for app in appliances for task in task_appliances[app]
                                    if app == appliances[3] and t_index == 0 and task == task_appliances[app][0]), 
                                   name = "starts_with_1st_task")

# %% [markdown]
# The dryer should start to run after the washing machine completed its task.
#
# $x_{t+1, u, {dry}, j_0}  <=  x_{t, u , {wash}, j_{last}}$
#
# $y_{t+1, u, {dry}, j_0}  <=  y_{t, u , {wash}, j_{last}}$
#
# $z_{t+1, u, {dry}, j_0}  <=  z_{t, u , {wash}, j_{last}}$
#
# $w_{t+1, u, {dry}, j_0}  <=  w_{t, u , {wash}, j_{last}}$
#
# $\forall t, = 2, 3, 4, . . .  96-1, u$

# %%
dryer_after_washer1 = m.addConstrs((x[time_slots[t_index + 1], u, 'dryer', 'drying1'] <= x[time_slots[t_index], u, 'washingmachine', '3rdrinse'] for t_index, t in enumerate(time_slots) for u in users if t_index != len(time_slots) -1), 
                                  name = 'dryer_after_washer1')

dryer_after_washer2 = m.addConstrs((y[time_slots[t_index + 1], u, 'dryer', 'drying1'] <= y[time_slots[t_index], u, 'washingmachine', '3rdrinse'] for t_index, t in enumerate(time_slots) for u in users if t_index != len(time_slots) -1), 
                                   name = 'dryer_after_washer2')

dryer_after_washer3 = m.addConstrs((z[time_slots[t_index + 1], u, 'dryer', 'drying1'] <= z[time_slots[t_index], u, 'washingmachine', '3rdrinse'] for t_index, t in enumerate(time_slots) for u in users if t_index != len(time_slots) -1), 
                                  name = 'dryer_after_washer3')

# %% [markdown]
# Runtime of the appliance has to satisified
#
# $\sum_t^{T} \sum_{j}^{J} x_{t, u, i, j} + y_{t, u, i, j} + z_{t, u, i, j}  == r_i$ $\forall u, i$

# %%
appliance_runtime = m.addConstrs((quicksum(x[t, u, app, task] + y[t, u, app, task] + z[t, u, app, task] for t in time_slots for task in task_appliances[app])== run_time[app] for u in users for app in appliances), 
                                                             name = "appliances_runtime")

# %% [markdown]
# All tasks of the Washing machine has to use either electricity or electricity and hotwater but not gas energy carrier.
#
# $z_{t, u, washingmachine,j_{wash}}$ = 0 $\forall t, u $

# %%
washingmachine_no_gas = m.addConstrs((z[t, u, app, task ] == 0 for t in time_slots for u in users for app in appliances for task in task_appliances[app] if app == appliances[0]), name = "washingmachine_no_gas")

# %% [markdown]
# All tasks of the dryer has to use either electricity or electricity and hotwater but not gas energy carrier.
#
# $z_{t, u, dryer,j_{dry}}$ = 0 $\forall t, u $

# %%
dryer_no_gas = m.addConstrs((z[t, u, app, task ] == 0 for t in time_slots for u in users for app in appliances for task in task_appliances[app]
                                     if app == appliances[1]), name = "dryer_no_gas")

# %% [markdown]
# All tasks of the dishwasher has to use either electricity or electricity and hotwater but not gas energy carrier.
#
# $z_{t, u, dishwasher,j_{dish}}$ = 0 $\forall t, u $

# %%
dishwasher_no_gas = m.addConstrs((z[t, u, app, task ] == 0 for t in time_slots for u in users for app in appliances for task in task_appliances[app]
                                     if app == appliances[2]), name = "dishwasher_no_gas")

# %% [markdown]
# All tasks of the gashob1 has to use gas energy carrier.
#
# $x_{t, u, gashob1,j_{hob1}}$ + $y_{t, u, gashob1,j_{hob1}}$ = 0 $\forall t, u$

# %%
gashob1_no_electricity_hotwater = m.addConstrs((x[t, u, app, task ] + y[t, u, app, task] == 0 for t in time_slots for u in users for app in appliances for task in task_appliances[app]
                                     if app == appliances[4]), name = "gashob1_no_electricity_hotwater")

# %% [markdown]
# All tasks of the gashob2 has to use gas energy carrier.
#
# $x_{t, u, gashob2,j_{hob2}}$ + $y_{t, u, gashob2,j_{hob2}}$  = 0 $\forall t, u$

# %%
gashob2_no_electricity_hotwaterr = m.addConstrs((x[t, u, app, task ] + y[t, u, app, task] == 0 for t in time_slots for u in users for app in appliances for task in task_appliances[app]
                                     if app == appliances[5]), name = "gashob2_no_electricity_hotwater")

# %% [markdown]
# First task of the appliance has to be start in between end time of the appliance minus run time of the appliance.
#
# $\sum_{t_{st}} ^ {t_{end}- r_i+1} x_{t, u, i, j_{0}} + y_{t, u, i, j_{0}} + z_{t, u, i, j_{0}} = 1$

# %%
appliance_first_task = m.addConstrs((quicksum(x[time_slots[t_index], u, app, task] + y[time_slots[t_index], u, app, task] + z[time_slots[t_index], u, app, task] 
                                              for t_index in range(starting_time_slot[app]-1, ending_time_slot[app]-run_time[app]+1)) == 1 
                                              for u in users for app in appliances for task in task_appliances[app] 
                                    if app != "refrigerator" and task == task_appliances[app][0]), name = "appliance_first_task")

# %% [markdown]
# # Update the Model

# %%
m.update()

# %% [markdown]
# # Call the Optimize Function

# %%
m.optimize()
# Out:
# Optimize a model with 1537296 rows, 1115040 columns and 5187528 nonzeros
# Variable types: 384 continuous, 1114656 integer (1114656 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+04]
#   Objective range  [1e-01, 7e+02]
#   Bounds range     [1e+00, 1e+05]
#   RHS range        [1e+00, 1e+05]
# Presolve removed 1535908 rows and 1114179 columns (presolve time = 5s) ...
# Presolve removed 1537200 rows and 1114541 columns
# Presolve time: 6.06s
# Presolved: 96 rows, 499 columns, 2899 nonzeros
# Variable types: 110 continuous, 389 integer (389 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -4.1022479e+06   6.088313e+03   0.000000e+00      7s
#       36    8.7032092e+04   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 8.703209e+04, 36 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    87032.092500 87032.0925  0.00%     -    7s
#
# Explored 0 nodes (36 simplex iterations) in 7.50 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 87032.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.703209250000e+04, best bound 8.703209250000e+04, gap 0.0000%

# %%
m.printAttr('X')
# Out:
#     Variable            X
# -------------------------
# x[k1,u1,refrigerator,cooling1]            1
# x[k1,u2,refrigerator,cooling1]            1
# x[k1,u3,refrigerator,cooling1]            1
# x[k1,u4,refrigerator,cooling1]            1
# x[k1,u5,refrigerator,cooling1]            1
# x[k1,u6,refrigerator,cooling1]            1
# x[k1,u7,refrigerator,cooling1]            1
# x[k1,u8,refrigerator,cooling1]            1
# x[k1,u9,refrigerator,cooling1]            1
# x[k1,u10,refrigerator,cooling1]            1
# x[k1,u11,refrigerator,cooling1]            1
# x[k1,u12,refrigerator,cooling1]            1
# x[k1,u13,refrigerator,cooling1]            1
# x[k1,u14,refrigerator,cooling1]            1
# x[k1,u15,refrigerator,cooling1]            1
# x[k1,u16,refrigerator,cooling1]            1
# x[k1,u17,refrigerator,cooling1]            1
# x[k1,u18,refrigerator,cooling1]            1
# x[k1,u19,refrigerator,cooling1]            1
# x[k1,u20,refrigerator,cooling1]            1
# x[k1,u21,refrigerator,cooling1]            1
# x[k1,u22,refrigerator,cooling1]            1
# x[k1,u23,refrigerator,cooling1]            1
# x[k1,u24,refrigerator,cooling1]            1
# x[k1,u25,refrigerator,cooling1]            1
# x[k1,u26,refrigerator,cooling1]            1
# x[k1,u27,refrigerator,cooling1]            1
# x[k1,u28,refrigerator,cooling1]            1
# x[k1,u29,refrigerator,cooling1]            1
# x[k1,u30,refrigerator,cooling1]            1
# x[k2,u1,refrigerator,cooling2]            1
# x[k2,u2,refrigerator,cooling2]            1
# x[k2,u3,refrigerator,cooling2]            1
# x[k2,u4,refrigerator,cooling2]            1
# x[k2,u5,refrigerator,cooling2]            1
# x[k2,u6,refrigerator,cooling2]            1
# x[k2,u7,refrigerator,cooling2]            1
# x[k2,u8,refrigerator,cooling2]            1
# x[k2,u9,refrigerator,cooling2]            1
# x[k2,u10,refrigerator,cooling2]            1
# x[k2,u11,refrigerator,cooling2]            1
# x[k2,u12,refrigerator,cooling2]            1
# x[k2,u13,refrigerator,cooling2]            1
# x[k2,u14,refrigerator,cooling2]            1
# x[k2,u15,refrigerator,cooling2]            1
# x[k2,u16,refrigerator,cooling2]            1
# x[k2,u17,refrigerator,cooling2]            1
# x[k2,u18,refrigerator,cooling2]            1
# x[k2,u19,refrigerator,cooling2]            1
# x[k2,u20,refrigerator,cooling2]            1
# x[k2,u21,refrigerator,cooling2]            1
# x[k2,u22,refrigerator,cooling2]            1
# x[k2,u23,refrigerator,cooling2]            1
# x[k2,u24,refrigerator,cooling2]            1
# x[k2,u25,refrigerator,cooling2]            1
# x[k2,u26,refrigerator,cooling2]            1
# x[k2,u27,refrigerator,cooling2]            1
# x[k2,u28,refrigerator,cooling2]            1
# x[k2,u29,refrigerator,cooling2]            1
# x[k2,u30,refrigerator,cooling2]            1
# x[k3,u1,refrigerator,cooling3]            1
# x[k3,u2,refrigerator,cooling3]            1
# x[k3,u3,refrigerator,cooling3]            1
# x[k3,u4,refrigerator,cooling3]            1
# x[k3,u5,refrigerator,cooling3]            1
# x[k3,u6,refrigerator,cooling3]            1
# x[k3,u7,refrigerator,cooling3]            1
# x[k3,u8,refrigerator,cooling3]            1
# x[k3,u9,refrigerator,cooling3]            1
# x[k3,u10,refrigerator,cooling3]            1
# x[k3,u11,refrigerator,cooling3]            1
# x[k3,u12,refrigerator,cooling3]            1
# x[k3,u13,refrigerator,cooling3]            1
# x[k3,u14,refrigerator,cooling3]            1
# x[k3,u15,refrigerator,cooling3]            1
# x[k3,u16,refrigerator,cooling3]            1
# x[k3,u17,refrigerator,cooling3]            1
# x[k3,u18,refrigerator,cooling3]            1
# x[k3,u19,refrigerator,cooling3]            1
# x[k3,u20,refrigerator,cooling3]            1
# x[k3,u21,refrigerator,cooling3]            1
# x[k3,u22,refrigerator,cooling3]            1
# x[k3,u23,refrigerator,cooling3]            1
# x[k3,u24,refrigerator,cooling3]            1
# x[k3,u25,refrigerator,cooling3]            1
# x[k3,u26,refrigerator,cooling3]            1
# x[k3,u27,refrigerator,cooling3]            1
# x[k3,u28,refrigerator,cooling3]            1
# x[k3,u29,refrigerator,cooling3]            1
# x[k3,u30,refrigerator,cooling3]            1
# x[k4,u1,refrigerator,cooling4]            1
# x[k4,u2,refrigerator,cooling4]            1
# x[k4,u3,refrigerator,cooling4]            1
# x[k4,u4,refrigerator,cooling4]            1
# x[k4,u5,refrigerator,cooling4]            1
# x[k4,u6,refrigerator,cooling4]            1
# x[k4,u7,refrigerator,cooling4]            1
# x[k4,u8,refrigerator,cooling4]            1
# x[k4,u9,refrigerator,cooling4]            1
# x[k4,u10,refrigerator,cooling4]            1
# x[k4,u11,refrigerator,cooling4]            1
# x[k4,u12,refrigerator,cooling4]            1
# x[k4,u13,refrigerator,cooling4]            1
# x[k4,u14,refrigerator,cooling4]            1
# x[k4,u15,refrigerator,cooling4]            1
# x[k4,u16,refrigerator,cooling4]            1
# x[k4,u17,refrigerator,cooling4]            1
# x[k4,u18,refrigerator,cooling4]            1
# x[k4,u19,refrigerator,cooling4]            1
# x[k4,u20,refrigerator,cooling4]            1
# x[k4,u21,refrigerator,cooling4]            1
# x[k4,u22,refrigerator,cooling4]            1
# x[k4,u23,refrigerator,cooling4]            1
# x[k4,u24,refrigerator,cooling4]            1
# x[k4,u25,refrigerator,cooling4]            1
# x[k4,u26,refrigerator,cooling4]            1
# x[k4,u27,refrigerator,cooling4]            1
# x[k4,u28,refrigerator,cooling4]            1
# x[k4,u29,refrigerator,cooling4]            1
# x[k4,u30,refrigerator,cooling4]            1
# x[k5,u1,refrigerator,cooling5]            1
# x[k5,u2,refrigerator,cooling5]            1
# x[k5,u3,refrigerator,cooling5]            1
# x[k5,u4,refrigerator,cooling5]            1
# x[k5,u5,refrigerator,cooling5]            1
# x[k5,u6,refrigerator,cooling5]            1
# x[k5,u7,refrigerator,cooling5]            1
# x[k5,u8,refrigerator,cooling5]            1
# x[k5,u9,refrigerator,cooling5]            1
# x[k5,u10,refrigerator,cooling5]            1
# x[k5,u11,refrigerator,cooling5]            1
# x[k5,u12,refrigerator,cooling5]            1
# x[k5,u13,refrigerator,cooling5]            1
# x[k5,u14,refrigerator,cooling5]            1
# x[k5,u15,refrigerator,cooling5]            1
# x[k5,u16,refrigerator,cooling5]            1
# x[k5,u17,refrigerator,cooling5]            1
# x[k5,u18,refrigerator,cooling5]            1
# x[k5,u19,refrigerator,cooling5]            1
# x[k5,u20,refrigerator,cooling5]            1
# x[k5,u21,refrigerator,cooling5]            1
# x[k5,u22,refrigerator,cooling5]            1
# x[k5,u23,refrigerator,cooling5]            1
# x[k5,u24,refrigerator,cooling5]            1
# x[k5,u25,refrigerator,cooling5]            1
# x[k5,u26,refrigerator,cooling5]            1
# x[k5,u27,refrigerator,cooling5]            1
# x[k5,u28,refrigerator,cooling5]            1
# x[k5,u29,refrigerator,cooling5]            1
# x[k5,u30,refrigerator,cooling5]            1
# x[k6,u1,refrigerator,cooling6]            1
# x[k6,u2,refrigerator,cooling6]            1
# x[k6,u3,refrigerator,cooling6]            1
# x[k6,u4,refrigerator,cooling6]            1
# x[k6,u5,refrigerator,cooling6]            1
# x[k6,u6,refrigerator,cooling6]            1
# x[k6,u7,refrigerator,cooling6]            1
# x[k6,u8,refrigerator,cooling6]            1
# x[k6,u9,refrigerator,cooling6]            1
# x[k6,u10,refrigerator,cooling6]            1
# x[k6,u11,refrigerator,cooling6]            1
# x[k6,u12,refrigerator,cooling6]            1
# x[k6,u13,refrigerator,cooling6]            1
# x[k6,u14,refrigerator,cooling6]            1
# x[k6,u15,refrigerator,cooling6]            1
# x[k6,u16,refrigerator,cooling6]            1
# x[k6,u17,refrigerator,cooling6]            1
# x[k6,u18,refrigerator,cooling6]            1
# x[k6,u19,refrigerator,cooling6]            1
# x[k6,u20,refrigerator,cooling6]            1
# x[k6,u21,refrigerator,cooling6]            1
# x[k6,u22,refrigerator,cooling6]            1
# x[k6,u23,refrigerator,cooling6]            1
# x[k6,u24,refrigerator,cooling6]            1
# x[k6,u25,refrigerator,cooling6]            1
# x[k6,u26,refrigerator,cooling6]            1
# x[k6,u27,refrigerator,cooling6]            1
# x[k6,u28,refrigerator,cooling6]            1
# x[k6,u29,refrigerator,cooling6]            1
# x[k6,u30,refrigerator,cooling6]            1
# x[k7,u1,refrigerator,cooling7]            1
# x[k7,u2,refrigerator,cooling7]            1
# x[k7,u3,refrigerator,cooling7]            1
# x[k7,u4,refrigerator,cooling7]            1
# x[k7,u5,refrigerator,cooling7]            1
# x[k7,u6,refrigerator,cooling7]            1
# x[k9,u13,refrigerator,cooling9]            1
# x[k9,u14,refrigerator,cooling9]            1
# x[k9,u15,refrigerator,cooling9]            1
# x[k9,u16,refrigerator,cooling9]            1
# x[k9,u17,refrigerator,cooling9]            1
# x[k9,u18,refrigerator,cooling9]            1
# x[k9,u19,refrigerator,cooling9]            1
# x[k9,u20,refrigerator,cooling9]            1
# x[k9,u21,refrigerator,cooling9]            1
# x[k9,u22,refrigerator,cooling9]            1
# x[k9,u23,refrigerator,cooling9]            1
# x[k9,u24,refrigerator,cooling9]            1
# x[k9,u25,refrigerator,cooling9]            1
# x[k9,u26,refrigerator,cooling9]            1
# x[k9,u27,refrigerator,cooling9]            1
# x[k9,u28,refrigerator,cooling9]            1
# x[k9,u29,refrigerator,cooling9]            1
# x[k9,u30,refrigerator,cooling9]            1
# x[k10,u1,refrigerator,cooling10]            1
# x[k10,u2,refrigerator,cooling10]            1
# x[k10,u3,refrigerator,cooling10]            1
# x[k10,u4,refrigerator,cooling10]            1
# x[k10,u5,refrigerator,cooling10]            1
# x[k10,u6,refrigerator,cooling10]            1
# x[k10,u7,refrigerator,cooling10]            1
# x[k10,u8,refrigerator,cooling10]            1
# x[k10,u9,refrigerator,cooling10]            1
# x[k10,u10,refrigerator,cooling10]            1
# x[k10,u11,refrigerator,cooling10]            1
# x[k10,u12,refrigerator,cooling10]            1
# x[k10,u13,refrigerator,cooling10]            1
# x[k10,u14,refrigerator,cooling10]            1
# x[k10,u15,refrigerator,cooling10]            1
# x[k10,u16,refrigerator,cooling10]            1
# x[k10,u17,refrigerator,cooling10]            1
# x[k10,u18,refrigerator,cooling10]            1
# x[k10,u19,refrigerator,cooling10]            1
# x[k10,u20,refrigerator,cooling10]            1
# x[k10,u21,refrigerator,cooling10]            1
# x[k10,u22,refrigerator,cooling10]            1
# x[k10,u23,refrigerator,cooling10]            1
# x[k10,u24,refrigerator,cooling10]            1
# x[k10,u25,refrigerator,cooling10]            1
# x[k10,u26,refrigerator,cooling10]            1
# x[k10,u27,refrigerator,cooling10]            1
# x[k10,u28,refrigerator,cooling10]            1
# x[k10,u29,refrigerator,cooling10]            1
# x[k10,u30,refrigerator,cooling10]            1
# x[k11,u1,refrigerator,cooling11]            1
# x[k11,u2,refrigerator,cooling11]            1
# x[k11,u3,refrigerator,cooling11]            1
# x[k11,u4,refrigerator,cooling11]            1
# x[k11,u5,refrigerator,cooling11]            1
# x[k11,u6,refrigerator,cooling11]            1
# x[k11,u7,refrigerator,cooling11]            1
# x[k11,u8,refrigerator,cooling11]            1
# x[k11,u9,refrigerator,cooling11]            1
# x[k11,u10,refrigerator,cooling11]            1
# x[k11,u11,refrigerator,cooling11]            1
# x[k11,u12,refrigerator,cooling11]            1
# x[k11,u13,refrigerator,cooling11]            1
# x[k11,u14,refrigerator,cooling11]            1
# x[k11,u15,refrigerator,cooling11]            1
# x[k11,u16,refrigerator,cooling11]            1
# x[k11,u17,refrigerator,cooling11]            1
# x[k11,u18,refrigerator,cooling11]            1
# x[k11,u19,refrigerator,cooling11]            1
# x[k22,u24,refrigerator,cooling22]            1
# x[k22,u25,refrigerator,cooling22]            1
# x[k22,u26,refrigerator,cooling22]            1
# x[k22,u27,refrigerator,cooling22]            1
# x[k22,u28,refrigerator,cooling22]            1
# x[k22,u29,refrigerator,cooling22]            1
# x[k22,u30,refrigerator,cooling22]            1
# x[k23,u1,refrigerator,cooling23]            1
# x[k23,u2,refrigerator,cooling23]            1
# x[k23,u3,refrigerator,cooling23]            1
# x[k23,u4,refrigerator,cooling23]            1
# x[k23,u5,refrigerator,cooling23]            1
# x[k23,u6,refrigerator,cooling23]            1
# x[k23,u7,refrigerator,cooling23]            1
# x[k23,u8,refrigerator,cooling23]            1
# x[k23,u9,refrigerator,cooling23]            1
# x[k23,u10,refrigerator,cooling23]            1
# x[k23,u11,refrigerator,cooling23]            1
# x[k23,u12,refrigerator,cooling23]            1
# x[k23,u13,refrigerator,cooling23]            1
# x[k23,u14,refrigerator,cooling23]            1
# x[k23,u15,refrigerator,cooling23]            1
# x[k23,u16,refrigerator,cooling23]            1
# x[k23,u17,refrigerator,cooling23]            1
# x[k23,u18,refrigerator,cooling23]            1
# x[k23,u19,refrigerator,cooling23]            1
# x[k23,u20,refrigerator,cooling23]            1
# x[k23,u21,refrigerator,cooling23]            1
# x[k23,u22,refrigerator,cooling23]            1
# x[k23,u23,refrigerator,cooling23]            1
# x[k23,u24,refrigerator,cooling23]            1
# x[k23,u25,refrigerator,cooling23]            1
# x[k23,u26,refrigerator,cooling23]            1
# x[k23,u27,refrigerator,cooling23]            1
# x[k23,u28,refrigerator,cooling23]            1
# x[k23,u29,refrigerator,cooling23]            1
# x[k23,u30,refrigerator,cooling23]            1
# x[k24,u1,refrigerator,cooling24]            1
# x[k24,u2,refrigerator,cooling24]            1
# x[k24,u3,refrigerator,cooling24]            1
# x[k24,u4,refrigerator,cooling24]            1
# x[k24,u5,refrigerator,cooling24]            1
# x[k24,u6,refrigerator,cooling24]            1
# x[k24,u7,refrigerator,cooling24]            1
# x[k24,u8,refrigerator,cooling24]            1
# x[k24,u9,refrigerator,cooling24]            1
# x[k24,u10,refrigerator,cooling24]            1
# x[k24,u11,refrigerator,cooling24]            1
# x[k24,u12,refrigerator,cooling24]            1
# x[k24,u13,refrigerator,cooling24]            1
# x[k24,u14,refrigerator,cooling24]            1
# x[k24,u15,refrigerator,cooling24]            1
# x[k24,u16,refrigerator,cooling24]            1
# x[k24,u17,refrigerator,cooling24]            1
# x[k24,u18,refrigerator,cooling24]            1
# x[k24,u19,refrigerator,cooling24]            1
# x[k24,u20,refrigerator,cooling24]            1
# x[k24,u21,refrigerator,cooling24]            1
# x[k24,u22,refrigerator,cooling24]            1
# x[k24,u23,refrigerator,cooling24]            1
# x[k24,u24,refrigerator,cooling24]            1
# x[k24,u25,refrigerator,cooling24]            1
# x[k24,u26,refrigerator,cooling24]            1
# x[k24,u27,refrigerator,cooling24]            1
# x[k24,u28,refrigerator,cooling24]            1
# x[k24,u29,refrigerator,cooling24]            1
# x[k24,u30,refrigerator,cooling24]            1
# x[k25,u1,refrigerator,cooling25]            1
# x[k25,u2,refrigerator,cooling25]            1
# x[k25,u3,refrigerator,cooling25]            1
# x[k25,u4,refrigerator,cooling25]            1
# x[k25,u5,refrigerator,cooling25]            1
# x[k25,u6,refrigerator,cooling25]            1
# x[k25,u7,refrigerator,cooling25]            1
# x[k25,u8,refrigerator,cooling25]            1
# x[k25,u9,refrigerator,cooling25]            1
# x[k25,u10,refrigerator,cooling25]            1
# x[k25,u11,refrigerator,cooling25]            1
# x[k25,u12,refrigerator,cooling25]            1
# x[k25,u13,refrigerator,cooling25]            1
# x[k25,u14,refrigerator,cooling25]            1
# x[k25,u15,refrigerator,cooling25]            1
# x[k25,u16,refrigerator,cooling25]            1
# x[k25,u17,refrigerator,cooling25]            1
# x[k25,u18,refrigerator,cooling25]            1
# x[k25,u19,refrigerator,cooling25]            1
# x[k25,u20,refrigerator,cooling25]            1
# x[k25,u21,refrigerator,cooling25]            1
# x[k25,u22,refrigerator,cooling25]            1
# x[k25,u23,refrigerator,cooling25]            1
# x[k25,u24,refrigerator,cooling25]            1
# x[k25,u25,refrigerator,cooling25]            1
# x[k25,u26,refrigerator,cooling25]            1
# x[k25,u27,refrigerator,cooling25]            1
# x[k25,u28,refrigerator,cooling25]            1
# x[k25,u29,refrigerator,cooling25]            1
# x[k25,u30,refrigerator,cooling25]            1
# x[k26,u1,refrigerator,cooling26]            1
# x[k26,u2,refrigerator,cooling26]            1
# x[k26,u3,refrigerator,cooling26]            1
# x[k26,u4,refrigerator,cooling26]            1
# x[k26,u5,refrigerator,cooling26]            1
# x[k26,u6,refrigerator,cooling26]            1
# x[k26,u7,refrigerator,cooling26]            1
# x[k26,u8,refrigerator,cooling26]            1
# x[k26,u9,refrigerator,cooling26]            1
# x[k26,u10,refrigerator,cooling26]            1
# x[k26,u11,refrigerator,cooling26]            1
# x[k26,u12,refrigerator,cooling26]            1
# x[k26,u13,refrigerator,cooling26]            1
# x[k26,u14,refrigerator,cooling26]            1
# x[k26,u15,refrigerator,cooling26]            1
# x[k26,u16,refrigerator,cooling26]            1
# x[k26,u17,refrigerator,cooling26]            1
# x[k26,u18,refrigerator,cooling26]            1
# x[k26,u19,refrigerator,cooling26]            1
# x[k26,u20,refrigerator,cooling26]            1
# x[k26,u21,refrigerator,cooling26]            1
# x[k26,u22,refrigerator,cooling26]            1
# x[k26,u23,refrigerator,cooling26]            1
# x[k26,u24,refrigerator,cooling26]            1
# x[k26,u25,refrigerator,cooling26]            1
# x[k26,u26,refrigerator,cooling26]            1
# x[k26,u27,refrigerator,cooling26]            1
# x[k26,u28,refrigerator,cooling26]            1
# x[k26,u29,refrigerator,cooling26]            1
# x[k26,u30,refrigerator,cooling26]            1
# x[k27,u1,refrigerator,cooling27]            1
# x[k27,u2,refrigerator,cooling27]            1
# x[k27,u3,refrigerator,cooling27]            1
# x[k27,u4,refrigerator,cooling27]            1
# x[k27,u5,refrigerator,cooling27]            1
# x[k27,u6,refrigerator,cooling27]            1
# x[k31,u21,refrigerator,cooling31]            1
# x[k31,u22,refrigerator,cooling31]            1
# x[k31,u23,refrigerator,cooling31]            1
# x[k31,u24,refrigerator,cooling31]            1
# x[k31,u25,refrigerator,cooling31]            1
# x[k31,u26,refrigerator,cooling31]            1
# x[k31,u27,refrigerator,cooling31]            1
# x[k31,u28,refrigerator,cooling31]            1
# x[k31,u29,refrigerator,cooling31]            1
# x[k31,u30,refrigerator,cooling31]            1
# x[k32,u1,refrigerator,cooling32]            1
# x[k32,u2,refrigerator,cooling32]            1
# x[k32,u3,refrigerator,cooling32]            1
# x[k32,u4,refrigerator,cooling32]            1
# x[k32,u5,refrigerator,cooling32]            1
# x[k32,u6,refrigerator,cooling32]            1
# x[k32,u7,refrigerator,cooling32]            1
# x[k32,u8,refrigerator,cooling32]            1
# x[k32,u9,refrigerator,cooling32]            1
# x[k32,u10,refrigerator,cooling32]            1
# x[k32,u11,refrigerator,cooling32]            1
# x[k32,u12,refrigerator,cooling32]            1
# x[k32,u13,refrigerator,cooling32]            1
# x[k32,u14,refrigerator,cooling32]            1
# x[k32,u15,refrigerator,cooling32]            1
# x[k32,u16,refrigerator,cooling32]            1
# x[k32,u17,refrigerator,cooling32]            1
# x[k32,u18,refrigerator,cooling32]            1
# x[k32,u19,refrigerator,cooling32]            1
# x[k32,u20,refrigerator,cooling32]            1
# x[k32,u21,refrigerator,cooling32]            1
# x[k32,u22,refrigerator,cooling32]            1
# x[k32,u23,refrigerator,cooling32]            1
# x[k32,u24,refrigerator,cooling32]            1
# x[k32,u25,refrigerator,cooling32]            1
# x[k32,u26,refrigerator,cooling32]            1
# x[k32,u27,refrigerator,cooling32]            1
# x[k32,u28,refrigerator,cooling32]            1
# x[k32,u29,refrigerator,cooling32]            1
# x[k32,u30,refrigerator,cooling32]            1
# x[k33,u1,refrigerator,cooling33]            1
# x[k33,u2,refrigerator,cooling33]            1
# x[k33,u3,refrigerator,cooling33]            1
# x[k33,u4,refrigerator,cooling33]            1
# x[k33,u5,refrigerator,cooling33]            1
# x[k33,u6,refrigerator,cooling33]            1
# x[k33,u7,refrigerator,cooling33]            1
# x[k33,u8,refrigerator,cooling33]            1
# x[k33,u9,refrigerator,cooling33]            1
# x[k33,u10,refrigerator,cooling33]            1
# x[k33,u11,refrigerator,cooling33]            1
# x[k33,u12,refrigerator,cooling33]            1
# x[k33,u13,refrigerator,cooling33]            1
# x[k33,u14,refrigerator,cooling33]            1
# x[k33,u15,refrigerator,cooling33]            1
# x[k33,u16,refrigerator,cooling33]            1
# x[k33,u17,refrigerator,cooling33]            1
# x[k33,u18,refrigerator,cooling33]            1
# x[k33,u19,refrigerator,cooling33]            1
# x[k33,u20,refrigerator,cooling33]            1
# x[k33,u21,refrigerator,cooling33]            1
# x[k33,u22,refrigerator,cooling33]            1
# x[k33,u23,refrigerator,cooling33]            1
# x[k33,u24,refrigerator,cooling33]            1
# x[k33,u25,refrigerator,cooling33]            1
# x[k33,u26,refrigerator,cooling33]            1
# x[k33,u27,refrigerator,cooling33]            1
# x[k33,u28,refrigerator,cooling33]            1
# x[k33,u29,refrigerator,cooling33]            1
# x[k33,u30,refrigerator,cooling33]            1
# x[k34,u1,refrigerator,cooling34]            1
# x[k34,u2,refrigerator,cooling34]            1
# x[k34,u3,refrigerator,cooling34]            1
# x[k34,u4,refrigerator,cooling34]            1
# x[k34,u5,refrigerator,cooling34]            1
# x[k34,u6,refrigerator,cooling34]            1
# x[k34,u7,refrigerator,cooling34]            1
# x[k34,u8,refrigerator,cooling34]            1
# x[k34,u9,refrigerator,cooling34]            1
# x[k34,u10,refrigerator,cooling34]            1
# x[k34,u11,refrigerator,cooling34]            1
# x[k34,u12,refrigerator,cooling34]            1
# x[k34,u13,refrigerator,cooling34]            1
# x[k34,u14,refrigerator,cooling34]            1
# x[k34,u15,refrigerator,cooling34]            1
# x[k34,u16,refrigerator,cooling34]            1
# x[k34,u17,refrigerator,cooling34]            1
# x[k34,u18,refrigerator,cooling34]            1
# x[k34,u19,refrigerator,cooling34]            1
# x[k34,u20,refrigerator,cooling34]            1
# x[k34,u21,refrigerator,cooling34]            1
# x[k34,u22,refrigerator,cooling34]            1
# x[k34,u23,refrigerator,cooling34]            1
# x[k34,u24,refrigerator,cooling34]            1
# x[k34,u25,refrigerator,cooling34]            1
# x[k34,u26,refrigerator,cooling34]            1
# ...
# z[k7,u23,gashob1,heating1]            1
# z[k7,u24,gashob1,heating4]            1
# z[k7,u25,gashob1,heating4]            1
# z[k7,u26,gashob1,heating1]            1
# z[k7,u27,gashob1,heating3]            1
# z[k7,u28,gashob1,heating2]            1
# z[k7,u29,gashob1,heating2]            1
# z[k7,u30,gashob1,heating1]            1
# z[k8,u1,gashob1,heating4]            1
# z[k8,u3,gashob1,heating4]            1
# z[k8,u5,gashob1,heating3]            1
# z[k8,u6,gashob1,heating3]            1
# z[k8,u8,gashob1,heating4]            1
# z[k8,u12,gashob1,heating3]            1
# z[k8,u13,gashob1,heating3]            1
# z[k8,u15,gashob1,heating2]            1
# z[k8,u16,gashob1,heating4]            1
# z[k8,u17,gashob1,heating2]            1
# z[k8,u19,gashob1,heating3]            1
# z[k8,u20,gashob1,heating3]            1
# z[k8,u21,gashob1,heating2]            1
# z[k8,u22,gashob1,heating3]            1
# z[k8,u23,gashob1,heating2]            1
# z[k8,u26,gashob1,heating2]            1
# z[k8,u27,gashob1,heating4]            1
# z[k8,u28,gashob1,heating3]            1
# z[k8,u29,gashob1,heating3]            1
# z[k8,u30,gashob1,heating2]            1
# z[k9,u5,gashob1,heating4]            1
# z[k9,u6,gashob1,heating4]            1
# z[k9,u12,gashob1,heating4]            1
# z[k9,u13,gashob1,heating4]            1
# z[k9,u15,gashob1,heating3]            1
# z[k9,u17,gashob1,heating3]            1
# z[k9,u19,gashob1,heating4]            1
# z[k9,u20,gashob1,heating4]            1
# z[k9,u21,gashob1,heating3]            1
# z[k9,u22,gashob1,heating4]            1
# z[k9,u23,gashob1,heating3]            1
# z[k9,u26,gashob1,heating3]            1
# z[k9,u28,gashob1,heating4]            1
# z[k9,u29,gashob1,heating4]            1
# z[k9,u30,gashob1,heating3]            1
# z[k10,u15,gashob1,heating4]            1
# z[k10,u17,gashob1,heating4]            1
# z[k10,u21,gashob1,heating4]            1
# z[k10,u23,gashob1,heating4]            1
# z[k10,u26,gashob1,heating4]            1
# z[k10,u30,gashob1,heating4]            1
# z[k52,u1,gashob2,heating1]            1
# z[k52,u10,gashob2,heating1]            1
# z[k52,u15,gashob2,heating1]            1
# z[k52,u16,gashob2,heating1]            1
# z[k52,u18,gashob2,heating1]            1
# z[k52,u28,gashob2,heating1]            1
# z[k53,u1,gashob2,heating2]            1
# z[k53,u10,gashob2,heating2]            1
# z[k53,u11,gashob2,heating1]            1
# z[k53,u12,gashob2,heating1]            1
# z[k53,u15,gashob2,heating2]            1
# z[k53,u16,gashob2,heating2]            1
# z[k53,u18,gashob2,heating2]            1
# z[k53,u20,gashob2,heating1]            1
# z[k53,u24,gashob2,heating1]            1
# z[k53,u28,gashob2,heating2]            1
# z[k54,u1,gashob2,heating3]            1
# z[k54,u10,gashob2,heating3]            1
# z[k54,u11,gashob2,heating2]            1
# z[k54,u12,gashob2,heating2]            1
# z[k54,u14,gashob2,heating1]            1
# z[k54,u15,gashob2,heating3]            1
# z[k54,u16,gashob2,heating3]            1
# z[k54,u18,gashob2,heating3]            1
# z[k54,u19,gashob2,heating1]            1
# z[k54,u20,gashob2,heating2]            1
# z[k54,u24,gashob2,heating2]            1
# z[k54,u25,gashob2,heating1]            1
# z[k54,u28,gashob2,heating3]            1
# z[k54,u30,gashob2,heating1]            1
# z[k55,u1,gashob2,heating4]            1
# z[k55,u6,gashob2,heating1]            1
# z[k55,u7,gashob2,heating1]            1
# z[k55,u9,gashob2,heating1]            1
# z[k55,u10,gashob2,heating4]            1
# z[k55,u11,gashob2,heating3]            1
# z[k55,u12,gashob2,heating3]            1
# z[k55,u13,gashob2,heating1]            1
# z[k55,u14,gashob2,heating2]            1
# z[k55,u15,gashob2,heating4]            1
# z[k55,u16,gashob2,heating4]            1
# z[k55,u18,gashob2,heating4]            1
# z[k55,u19,gashob2,heating2]            1
# z[k55,u20,gashob2,heating3]            1
# z[k55,u22,gashob2,heating1]            1
# z[k55,u24,gashob2,heating3]            1
# z[k55,u25,gashob2,heating2]            1
# z[k55,u28,gashob2,heating4]            1
# z[k55,u30,gashob2,heating2]            1
# z[k56,u1,gashob2,heating5]            1
# z[k56,u2,gashob2,heating1]            1
# z[k56,u3,gashob2,heating1]            1
# z[k56,u5,gashob2,heating1]            1
# z[k56,u6,gashob2,heating2]            1
# z[k56,u7,gashob2,heating2]            1
# z[k56,u9,gashob2,heating2]            1
# z[k56,u10,gashob2,heating5]            1
# z[k56,u11,gashob2,heating4]            1
# z[k56,u12,gashob2,heating4]            1
# z[k56,u13,gashob2,heating2]            1
# z[k56,u14,gashob2,heating3]            1
# z[k56,u15,gashob2,heating5]            1
# z[k56,u16,gashob2,heating5]            1
# z[k56,u17,gashob2,heating1]            1
# z[k56,u18,gashob2,heating5]            1
# z[k56,u19,gashob2,heating3]            1
# z[k56,u20,gashob2,heating4]            1
# z[k56,u22,gashob2,heating2]            1
# z[k56,u23,gashob2,heating1]            1
# z[k56,u24,gashob2,heating4]            1
# z[k56,u25,gashob2,heating3]            1
# z[k56,u28,gashob2,heating5]            1
# z[k56,u29,gashob2,heating1]            1
# z[k56,u30,gashob2,heating3]            1
# z[k57,u1,gashob2,heating6]            1
# z[k57,u2,gashob2,heating2]            1
# z[k57,u3,gashob2,heating2]            1
# z[k57,u5,gashob2,heating2]            1
# z[k57,u6,gashob2,heating3]            1
# z[k57,u7,gashob2,heating3]            1
# z[k57,u9,gashob2,heating3]            1
# z[k57,u10,gashob2,heating6]            1
# z[k57,u11,gashob2,heating5]            1
# z[k57,u12,gashob2,heating5]            1
# z[k57,u13,gashob2,heating3]            1
# z[k57,u14,gashob2,heating4]            1
# z[k57,u15,gashob2,heating6]            1
# z[k57,u16,gashob2,heating6]            1
# z[k57,u17,gashob2,heating2]            1
# z[k57,u18,gashob2,heating6]            1
# z[k57,u19,gashob2,heating4]            1
# z[k57,u20,gashob2,heating5]            1
# z[k57,u21,gashob2,heating1]            1
# z[k57,u22,gashob2,heating3]            1
# z[k57,u23,gashob2,heating2]            1
# z[k57,u24,gashob2,heating5]            1
# z[k57,u25,gashob2,heating4]            1
# z[k57,u27,gashob2,heating1]            1
# z[k57,u28,gashob2,heating6]            1
# z[k57,u29,gashob2,heating2]            1
# z[k57,u30,gashob2,heating4]            1
# z[k58,u2,gashob2,heating3]            1
# z[k58,u3,gashob2,heating3]            1
# z[k58,u5,gashob2,heating3]            1
# z[k58,u6,gashob2,heating4]            1
# z[k58,u7,gashob2,heating4]            1
# z[k58,u9,gashob2,heating4]            1
# z[k58,u11,gashob2,heating6]            1
# z[k58,u12,gashob2,heating6]            1
# z[k58,u13,gashob2,heating4]            1
# z[k58,u14,gashob2,heating5]            1
# z[k58,u17,gashob2,heating3]            1
# z[k58,u19,gashob2,heating5]            1
# z[k58,u20,gashob2,heating6]            1
# z[k58,u21,gashob2,heating2]            1
# z[k58,u22,gashob2,heating4]            1
# z[k58,u23,gashob2,heating3]            1
# z[k58,u24,gashob2,heating6]            1
# z[k58,u25,gashob2,heating5]            1
# z[k58,u27,gashob2,heating2]            1
# z[k58,u29,gashob2,heating3]            1
# z[k58,u30,gashob2,heating5]            1
# z[k59,u2,gashob2,heating4]            1
# z[k59,u3,gashob2,heating4]            1
# z[k59,u4,gashob2,heating1]            1
# z[k59,u5,gashob2,heating4]            1
# z[k59,u6,gashob2,heating5]            1
# z[k59,u7,gashob2,heating5]            1
# z[k59,u8,gashob2,heating1]            1
# z[k59,u9,gashob2,heating5]            1
# z[k59,u13,gashob2,heating5]            1
# z[k59,u14,gashob2,heating6]            1
# z[k59,u17,gashob2,heating4]            1
# z[k59,u19,gashob2,heating6]            1
# z[k59,u21,gashob2,heating3]            1
# z[k59,u22,gashob2,heating5]            1
# z[k59,u23,gashob2,heating4]            1
# z[k59,u25,gashob2,heating6]            1
# z[k59,u26,gashob2,heating1]            1
# z[k59,u27,gashob2,heating3]            1
# z[k59,u29,gashob2,heating4]            1
# z[k59,u30,gashob2,heating6]            1
# z[k60,u2,gashob2,heating5]            1
# z[k60,u3,gashob2,heating5]            1
# z[k60,u4,gashob2,heating2]            1
# z[k60,u5,gashob2,heating5]            1
# z[k60,u6,gashob2,heating6]            1
# z[k60,u7,gashob2,heating6]            1
# z[k60,u8,gashob2,heating2]            1
# z[k60,u9,gashob2,heating6]            1
# z[k60,u13,gashob2,heating6]            1
# z[k60,u17,gashob2,heating5]            1
# z[k60,u21,gashob2,heating4]            1
# z[k60,u22,gashob2,heating6]            1
# z[k60,u23,gashob2,heating5]            1
# z[k60,u26,gashob2,heating2]            1
# z[k60,u27,gashob2,heating4]            1
# z[k60,u29,gashob2,heating5]            1
# z[k61,u2,gashob2,heating6]            1
# z[k61,u3,gashob2,heating6]            1
# z[k61,u4,gashob2,heating3]            1
# z[k61,u5,gashob2,heating6]            1
# z[k61,u8,gashob2,heating3]            1
# z[k61,u17,gashob2,heating6]            1
# z[k61,u21,gashob2,heating5]            1
# z[k61,u23,gashob2,heating6]            1
# z[k61,u26,gashob2,heating3]            1
# z[k61,u27,gashob2,heating5]            1
# z[k61,u29,gashob2,heating6]            1
# z[k62,u4,gashob2,heating4]            1
# z[k62,u8,gashob2,heating4]            1
# z[k62,u21,gashob2,heating6]            1
# z[k62,u26,gashob2,heating4]            1
# z[k62,u27,gashob2,heating6]            1
# z[k63,u4,gashob2,heating5]            1
# z[k63,u8,gashob2,heating5]            1
# z[k63,u26,gashob2,heating5]            1
# z[k64,u4,gashob2,heating6]            1
# z[k64,u8,gashob2,heating6]            1
# z[k64,u26,gashob2,heating6]            1
#        s[k1]            1
#        s[k2]            1
#        s[k3]            1
#        s[k4]            1
#        s[k5]            1
#        s[k6]            1
#        s[k7]            1
#        s[k8]            1
#        s[k9]            1
#       s[k10]            1
#       s[k11]            1
#       s[k12]            1
#       s[k13]            1
#       s[k14]            1
#       s[k15]            1
#       s[k16]            1
#       s[k17]            1
#       s[k18]            1
#       s[k19]            1
#       s[k20]            1
#       s[k21]            1
#       s[k22]            1
#       s[k23]            1
#       s[k24]            1
#       s[k25]            1
#       s[k26]            1
#       s[k27]            1
#       s[k28]            1
#       s[k29]            1
#       s[k30]            1
#       s[k31]            1
#       s[k32]            1
#       s[k33]            1
#       s[k34]            1
#       s[k35]            1
#       s[k36]            1
#       s[k37]            1
#       s[k38]            1
#       s[k39]            1
#       s[k40]            1
#       s[k41]            1
#       s[k42]            1
#       s[k43]            1
#       s[k44]            1
#       s[k45]            1
#       s[k46]            1
#       s[k47]            1
#       s[k48]            1
#       s[k49]            1
#       s[k50]            1
#       s[k51]            1
#       s[k52]            1
#       s[k53]            1
#       s[k54]            1
#       s[k55]            1
#       s[k56]            1
#       s[k57]            1
#       s[k58]            1
#       s[k59]            1
#       s[k60]            1
#       s[k61]            1
#       s[k62]            1
#       s[k63]            1
#       s[k64]            1
#       s[k65]            1
#       s[k66]            1
#       s[k67]            1
#       s[k68]            1
#       s[k69]            1
#       s[k70]            1
#       s[k71]            1
#       s[k72]            1
#       s[k73]            1
#       s[k74]            1
#       s[k75]            1
#       s[k76]            1
#       s[k77]            1
#       s[k78]            1
#       s[k79]            1
#       s[k80]            1
#       s[k81]            1
#       s[k82]            1
#       s[k83]            1
#       s[k84]            1
#       s[k85]            1
#       s[k86]            1
#       s[k87]            1
#       s[k88]            1
#       s[k89]            1
#       s[k90]            1
#       s[k91]            1
#       s[k92]            1
#       s[k93]            1
#       s[k94]            1
#       s[k95]            1
#       s[k96]            1
# available_hotwater_storagetank[k1]         3170
# available_hotwater_storagetank[k2]         3170
# available_hotwater_storagetank[k3]         3170
# available_hotwater_storagetank[k4]         3170
# available_hotwater_storagetank[k5]         3170
# available_hotwater_storagetank[k6]         3170
# available_hotwater_storagetank[k7]         3170
# available_hotwater_storagetank[k8]         3170
# available_hotwater_storagetank[k9]         3170
# available_hotwater_storagetank[k10]         3170
# available_hotwater_storagetank[k11]         3170
# available_hotwater_storagetank[k12]         3170
# available_hotwater_storagetank[k13]         3170
# available_hotwater_storagetank[k14]         3170
# available_hotwater_storagetank[k15]         3170
# available_hotwater_storagetank[k16]         3170
# available_hotwater_storagetank[k17]         3170
# available_hotwater_storagetank[k18]         3170
# available_hotwater_storagetank[k19]         3170
# available_hotwater_storagetank[k20]         3170
# available_hotwater_storagetank[k21]         3170
# available_hotwater_storagetank[k22]         3170
# available_hotwater_storagetank[k23]         3170
# available_hotwater_storagetank[k24]         3170
# available_hotwater_storagetank[k25]         3170
# available_hotwater_storagetank[k26]         3170
# available_hotwater_storagetank[k27]         3170
# available_hotwater_storagetank[k28]         3170
# available_hotwater_storagetank[k29]         3170
# available_hotwater_storagetank[k30]         3170
# available_hotwater_storagetank[k31]         3170
# available_hotwater_storagetank[k32]         3170
# available_hotwater_storagetank[k33]         3170
# available_hotwater_storagetank[k34]         3170
# available_hotwater_storagetank[k35]         3170
# available_hotwater_storagetank[k36]         3170
# available_hotwater_storagetank[k37]       3032.5
# available_hotwater_storagetank[k38]       2832.5
# available_hotwater_storagetank[k39]       2832.5
# available_hotwater_storagetank[k40]       2832.5
# available_hotwater_storagetank[k41]       2832.5
# available_hotwater_storagetank[k42]       2832.5
# available_hotwater_storagetank[k43]       2382.5
# available_hotwater_storagetank[k44]       1932.5
# available_hotwater_storagetank[k45]       1482.5
# available_hotwater_storagetank[k46]       1132.5
# available_hotwater_storagetank[k47]        857.5
# available_hotwater_storagetank[k48]        672.5
# available_hotwater_storagetank[k49]        622.5
# available_hotwater_storagetank[k50]        572.5
# available_hotwater_storagetank[k51]        572.5
# available_hotwater_storagetank[k52]        572.5
# available_hotwater_storagetank[k53]        572.5
# available_hotwater_storagetank[k54]        572.5
# available_hotwater_storagetank[k55]        572.5
# available_hotwater_storagetank[k56]        572.5
# available_hotwater_storagetank[k57]        572.5
# available_hotwater_storagetank[k58]        572.5
# available_hotwater_storagetank[k59]        572.5
# available_hotwater_storagetank[k60]        572.5
# available_hotwater_storagetank[k61]        572.5
# available_hotwater_storagetank[k62]        572.5
# available_hotwater_storagetank[k63]        572.5
# available_hotwater_storagetank[k64]        572.5
# available_hotwater_storagetank[k65]        572.5
# available_hotwater_storagetank[k66]        572.5
# available_hotwater_storagetank[k67]        572.5
# available_hotwater_storagetank[k68]        572.5
# available_hotwater_storagetank[k69]        572.5
# available_hotwater_storagetank[k70]        572.5
# available_hotwater_storagetank[k71]        572.5
# available_hotwater_storagetank[k72]        572.5
# available_hotwater_storagetank[k73]        322.5
# available_hotwater_storagetank[k74]        322.5
# available_hotwater_storagetank[k75]        322.5
# available_hotwater_storagetank[k76]        322.5
# available_hotwater_storagetank[k77]         72.5
# available_hotwater_storagetank[k78]         17.5

# %% [markdown]
# Create a nice overview per time slot in HTML.

# %%
output = "<h1>Scheduling plan</h1><table><thead><tr><td></td><td><b>Only Electricity</b></td><td><b>Electricity and Hotwater</b></td><td><b>Gas</b></td><td><b>Avaible hotwater</b></td></tr></thead>"

for time in time_slots:
    output += "<tbody><tr><td><b>{}</b></td><td style='text-align: right'>".format(time)
    
    #only electricity
    for u in users:
        for app in appliances:
            for task in task_appliances[app]:
                if x[time, u, app, task].X>0:
                    output += "task <b>{}</b> of appliance <b>{}</b> of user <b>{}</b> at time slot <b>{}</b> uses only electricity <b>{}</b><br/>".format(task, app, u, time, x[time, u, app, task].X)
    
    #electricity and hotwater
    output += "</td><td style='text-align: right'>"
    for u in users:
        for app in appliances:
            for task in task_appliances[app]:
                if y[time, u, app, task].X>0:
                    output += "task <b>{}</b> of appliance <b>{}</b> of user <b>{}</b> at time slot <b>{}</b> uses electricity and hotwater <b>{}</b><br/>".format(task, app, u, time, y[time, u, app, task].X)
    #only Gas
    output += "</td><td style='text-align: right'>"
    for u in users:
        for app in appliances:
            for task in task_appliances[app]:
                if z[time, u, app, task].X>0:
                    output += "task <b>{}</b> of appliance <b>{}</b> of user <b>{}</b> at time slot <b>{}</b> uses only gas <b>{}</b><br/>".format(task, app, u, time, z[time, u, app, task].X) 
    

    #Available water in storage tank
    output += "</td><td style='text-align: right'>"
    if available_hotwater_storagetank[time].X>0:
        output += "available hot water <b>{}</b>wH in storage tank at time slot <b>{}</b><br/>".format(available_hotwater_storagetank[time].X, time)  
    
    output += "</td></tr></tbody>"

output += "</table>"

from IPython.display import HTML, display
display(HTML(output))

f = open("output.html", "w+")
f.write(output)
f.close()
# Out:
# <h1>Scheduling plan</h1><table><thead><tr><td></td><td><b>Only Electricity</b></td><td><b>Electricity and Hotwater</b></td><td><b>Gas</b></td><td><b>Avaible hotwater</b></td></tr></thead><tbody><tr><td><b>k1</b></td><td style='text-align: right'>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u1</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u2</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u3</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u4</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u5</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u6</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u7</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u8</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u9</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u10</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u11</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u12</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u13</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u14</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u15</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u16</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u17</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u18</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u19</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u20</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u21</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u22</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u23</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u24</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u25</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u26</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u27</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>refrigerator</b> of user <b>u28</b> at time slot <b>k1</b> uses only electricity <b>1.0</b><br/>task <b>cooling1</b> of appliance <b>re ...
