# %% [markdown]
# # Users with hybrid mode and mixed time range

# %% [markdown]
# # 10% of users allowed their appliances to operate on hybrid mode and mixed time range, 90% users with standard mode and fixed time range.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
SUB = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉")
co2 = "CO2".translate(SUB)

# %%
x = np.arange(1, 97, 1)
y_CO2_electricity = [0.487, 0.485, 0.480, 0.478, 0.478, 0.475, 0.472, 0.470, 0.470, 0.468, 0.465, 0.460, 0.457,0.456,
        0.451, 0.452, 0.452, 0.450, 0.448, 0.443, 0.438, 0.438, 0.440, 0.440, 0.437, 0.435, 0.435, 0.436,
        0.437, 0.437, 0.438, 0.438, 0.438, 0.441, 0.443, 0.449, 0.455, 0.460, 0.464, 0.467, 0.481, 0.489, 0.495, 0.497,
        0.504, 0.509, 0.514, 0.520, 0.536, 0.549, 0.554, 0.559, 0.565, 0.569, 0.571, 0.571, 0.558, 0.562, 0.570, 0.574,
        0.567, 0.572, 0.572, 0.568, 0.567, 0.563, 0.558, 0.555, 0.554, 0.552, 0.551, 0.549, 0.542, 0.540, 0.542, 0.543,
        0.544, 0.547, 0.576, 0.549, 0.552, 0.557, 0.557, 0.560, 0.563, 0.563, 0.563, 0.567, 0.568, 0.566, 0.561,
        0.550, 0.548, 0.541, 0.532,0.524]

# %%
y_electricity10 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,82.5,2122.5,1110,82.5,1110,1260,45,1185,1860,13657.5,7260,1860,832.5,3210,1522.5,13507.5,14535,14535,10807.5,9810,7380,7.5,1035,1035,7.5,1035,1035,7.5,1575,14535,547.5,1575,1575,13507.5,3060,2047.5,67.5,1785,1095,67.5,1095,1785,67.5,1095,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity10, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption during 10% user possess hybrid energy carrier and allows mixed time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 20% of users allowed their appliances to operate on hybrid mode and mixed time range, 80% users with standard mode and fixed time range.

# %%
y_electricity20 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,157.5,3210,1185,157.5,1185,1485,82.5,1335,1935,12307.5,6735,1935,907.5,3135,1635,12007.5,13035,13035,9607.5,8835,6675,7.5,1035,1035,7.5,1035,1035,7.5,1515,13035,487.5,1515,1515,12007.5,2835,1935,127.5,2535,1155,127.5,1155,2535,127.5,1155,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity20, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption during 20% user possess hybrid energy carrier and allows mixed time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 30% of users allowed their appliances to operate on hybrid mode and mixed time range, 70% users with standard mode and fixed time range.

# %%
y_electricity30 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,232.5,4297.5,1260,232.5,1260,1710,120,1485,2010,10957.5,6210,2010,982.5,3060,1747.5,10507.5,11535,11535,8407.5,7860,5970,7.5,1035,1035,7.5,1035,1035,7.5,1455,11535,427.5,1455,1455,10507.5,2610,1822.5,187.5,3285,1215,187.5,1215,3285,187.5,1215,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity30, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption during 30% user possess hybrid energy carrier and allows mixed time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 40% of users allowed their appliances to operate on hybrid mode and mixed time range, 60% users with standard mode and fixed time range.

# %%
y_electricity40 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,307.5,5385,1335,307.5,1335,1935,157.5,1635,2085,9007.5,5685,2085,1057.5,2985,1860,9007.5,10035,10035,7207.5,6885,5265,7.5,1035,1035,7.5,1035,1035,7.5,1395,10035,367.5,1395,1395,9007.5,2385,1710,247.5,4035,1275,247.5,1275,4035,247.5,1275,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity40, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption during 40% user possess hybrid energy carrier and allows mixed time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 50% of users allowed their appliances to operate on hybrid mode and mixed time range, 50% users with standard mode and fixed time range.

# %%
y_electricity50 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,382.5,6472.5,1410,382.5,1410,2160,195,1785,2160,8257.5,5160,2160,1132.5,2910,1972.5,7507.5,8535,8535,6007.5,5910,4560,7.5,1035,1035,7.5,1035,1035,7.5,1335,8535,307.5,1335,1335,7507.5,2160,1597.5,307.5,4785,1335,307.5,1335,4785,307.5,1335,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity50, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption during 50% user possess hybrid energy carrier and allows mixed time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 60% of users allowed their appliances to operate on hybrid mode and mixed time range, 40% users with standard mode and fixed time range.

# %%
y_electricity60 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,457.5,7560,1485,457.5,1485,2385,232.5,1935,2235,6907.5,4635,2235,1207.5,2835,2085,6007.5,7035,7035,4807.5,4935,3855,7.5,1035,1035,7.5,1035,1035,7.5,1275,7035,247.5,1275,1275,6007.5,1935,1485,367.5,5535,1395,367.5,1395,5535,367.5,1395,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity60, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption during 60% user possess hybrid energy carrier and allows mixed time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 70% of users allowed their appliances to operate on hybrid mode and mixed time range, 30% users with standard mode and fixed time range.

# %%
y_electricity70 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,532.5,8647.5,1560,532.5,1560,2610,270,2085,2310,5557.5,4110,2310,1282.5,2760,2197.5,4507.5,5535,5535,3607.5,3960,3150,7.5,1035,1035,7.5,1035,1035,7.5,1215,5535,187.5,1215,1215,4507.5,1710,1372.5,427.5,6285,1455,427.5,1455,6285,427.5,1455,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity70, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption during 70% user possess hybrid energy carrier and allows mixed time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 80% of users allowed their appliances to operate on hybrid mode and mixed time range, 20% users with standard mode and fixed time range.

# %%
y_electricity80 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,607.5,9735,1635,607.5,1635,2835,307.5,2235,2385,4207.5,3585,2385,1357.5,2685,2310,3007.5,4035,4035,2407.5,2985,2445,7.5,1035,1035,7.5,1035,1035,7.5,1155,4035,127.5,1155,1155,3007.5,1485,1260,487.5,7035,1515,487.5,1515,7035,487.5,1515,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity80, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption during 80% user possess hybrid energy carrier and allows mixed time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 90% of users allowed their appliances to operate on hybrid mode and mixed time range, 10% users with standard mode and fixed time range.

# %%
y_electricity90 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,682.5,10822.5,1710,682.5,1710,3060,345,2385,2460,2460,3060,2460,1432.5,2610,2422.5,1507.5,2535,2535,1207.5,2010,1740,7.5,1035,1035,7.5,1035,1035,7.5,1095,2535,67.5,1095,1095,1507.5,1260,1147.5,547.5,7785,1575,547.5,1575,7785,547.5,1575,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5
]

# %%
# fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity90, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption during 90% user possess hybrid energy carrier and allows mixed time range', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 100% of users allowed their appliances to operate on hybrid mode and mixed time range.

# %%
y_electricity100 = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,757.5,11910,1785,757.5,1785,3285,382.5,2535,2535,1507.5,2535,2535,1507.5,2535,2535,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,607.5,8535,1635,607.5,1635,8535,607.5,1635,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity100, color = 'b', label = 'Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15AM Hours) to 96(6:00AM Hours) each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('g'+co2+'/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption during 100% user possess hybrid energy carrier and allows mixed time range', va='baseline', fontsize='15')
fig.tight_layout()
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.text(0.3, 0.3, "OFF PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
fig.text(0.6, 0.95, "ON PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
fig.text(0.35, 0.7,"MID PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
plt.show()
