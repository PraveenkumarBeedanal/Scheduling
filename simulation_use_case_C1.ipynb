# %% [markdown]
# # Users with mixed time range, but standard energy carrier.

# %% [markdown]
# # 10% of users with mixed time range, 90% of user fixed time range and 100% of users allowed their appliances to operate on standard mode.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
SUB = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉")
co2 = "CO2".translate(SUB)

# %%
x = np.arange(1, 97, 1)

y_CO2_electricity = [0.487, 0.485, 0.480, 0.478, 0.478, 0.475, 0.472, 0.470, 0.470, 0.468, 0.465, 0.460, 0.457,0.456,
        0.451, 0.452, 0.452, 0.450, 0.448, 0.443, 0.438, 0.438, 0.440, 0.440, 0.437, 0.435, 0.435, 0.436,
        0.437, 0.437, 0.438, 0.438, 0.438, 0.441, 0.443, 0.449, 0.455, 0.460, 0.464, 0.467, 0.481, 0.489, 0.495, 0.497,
        0.504, 0.509, 0.514, 0.520, 0.536, 0.549, 0.554, 0.559, 0.565, 0.569, 0.571, 0.571, 0.558, 0.562, 0.570, 0.574,
        0.567, 0.572, 0.572, 0.568, 0.567, 0.563, 0.558, 0.555, 0.554, 0.552, 0.551, 0.549, 0.542, 0.540, 0.542, 0.543,
        0.544, 0.547, 0.576, 0.549, 0.552, 0.557, 0.557, 0.560, 0.563, 0.563, 0.563, 0.567, 0.568, 0.566, 0.561,
        0.550, 0.548, 0.541, 0.532,0.524]

y_electricity10 = [1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 
                  7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 
                  7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 82.5, 2535.0, 1710.0, 82.5, 1110.0, 1260.0, 45.0, 2535.0,
                  3210.0, 15007.5, 8310.0, 2685.0, 1387.5, 3060.0, 1372.5, 13507.5, 14535.0, 14535.0, 10807.5, 9810.0,
                  7380.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1575.0, 14535.0, 547.5, 1575.0, 1575.0, 13507.5,
                  3060.0, 2047.5, 67.5, 2535.0, 1095.0, 67.5, 1095.0, 2535.0, 232.5, 1147.5, 1035.0, 7.5, 1035.0, 1035.0, 
                  7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity10, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity load pattern where 10% user possess mixed time range but not Energy carrier', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 20% of users with mixed time range, 80% of user fixed time range and 100% of users allowed their appliances to operate on standard mode.

# %%
y_electricity20 = [1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 157.5, 4035.0, 2385.0, 157.5, 1185.0, 1485.0, 82.5, 4035.0, 4635.0, 15007.5, 8835.0, 3585.0, 2017.5, 2835.0, 1335.0, 12007.5, 13035.0, 13035.0, 9607.5, 8835.0, 6675.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1515.0, 13035.0, 487.5, 1515.0, 1515.0, 12007.5, 2835.0, 1935.0, 127.5, 4035.0, 1155.0, 127.5, 1155.0, 4035.0, 457.5, 1260.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity20, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label=co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity load pattern where 20% user possess mixed time range but not Energy carrier', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 30% of users with mixed time range, 70% of user fixed time range and 100% of users allowed their appliances to operate on standard mode.

# %%
y_electricity30 = [1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 232.5, 5535.0, 3060.0, 232.5, 1260.0, 1710.0, 120.0, 5535.0, 6060.0, 15007.5, 9360.0, 4485.0, 2647.5, 2610.0, 1297.5, 10507.5, 11535.0, 11535.0, 8407.5, 7860.0, 5970.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1455.0, 11535.0, 427.5, 1455.0, 1455.0, 10507.5, 2610.0, 1822.5, 187.5, 5535.0, 1215.0, 187.5, 1215.0, 5535.0, 682.5, 1372.5, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity30, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label=co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity load pattern where 30% user possess mixed time range but not Energy carrier', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 40% of users with mixed time range, 60% of user fixed time range and 100% of users allowed their appliances to operate on standard mode.

# %%
y_electricity40 = [1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 307.5, 7035.0, 3735.0, 307.5, 1335.0, 1935.0, 157.5, 7035.0, 7485.0, 15007.5, 9885.0, 5385.0, 3277.5, 2385.0, 1260.0, 9007.5, 10035.0, 10035.0, 7207.5, 6885.0, 5265.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1395.0, 10035.0, 367.5, 1395.0, 1395.0, 9007.5, 2385.0, 1710.0, 247.5, 7035.0, 1275.0, 247.5, 1275.0, 7035.0, 907.5, 1485.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity40, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label=co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity load pattern where 40% user possess mixed time range but not Energy carrier', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 50% of users with mixed time range, 50% of user fixed time range and 100% of users allowed their appliances to operate on standard mode.

# %%
y_electricity50 = [1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 382.5, 8535.0, 4410.0, 382.5, 1410.0, 2160.0, 195.0, 8535.0, 8910.0, 15007.5, 10410.0, 6285.0, 3907.5, 2160.0, 1222.5, 7507.5, 8535.0, 8535.0, 6007.5, 5910.0, 4560.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1335.0, 8535.0, 307.5, 1335.0, 1335.0, 7507.5, 2160.0, 1597.5, 307.5, 8535.0, 1335.0, 307.5, 1335.0, 8535.0, 1132.5, 1597.5, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity40, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label=co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity load pattern where 50% user possess mixed time range but not Energy carrier', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 60% of users with mixed time range, 40% of user fixed time range and 100% of users allowed their appliances to operate on standard mode.

# %%
y_electricity60 = [1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 457.5, 10035.0, 5085.0, 457.5, 1485.0, 2385.0, 232.5, 10035.0, 10335.0, 15007.5, 10935.0, 7185.0, 4537.5, 1935.0, 1185.0, 6007.5, 7035.0, 7035.0, 4807.5, 4935.0, 3855.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1275.0, 7035.0, 247.5, 1275.0, 1275.0, 6007.5, 1935.0, 1485.0, 367.5, 10035.0, 1395.0, 367.5, 1395.0, 10035.0, 1357.5, 1710.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity60, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label=co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity load pattern where 60% user possess mixed time range but not Energy carrier', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 70% of users with mixed time range, 30% of user fixed time range and 100% of users allowed their appliances to operate on standard mode.

# %%
y_electricity70 = [1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 532.5, 11535.0, 5760.0, 532.5, 1560.0, 2610.0, 270.0, 11535.0, 11760.0, 15007.5, 11460.0, 8085.0, 5167.5, 1710.0, 1147.5, 4507.5, 5535.0, 5535.0, 3607.5, 3960.0, 3150.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1215.0, 5535.0, 187.5, 1215.0, 1215.0, 4507.5, 1710.0, 1372.5, 427.5, 11535.0, 1455.0, 427.5, 1455.0, 11535.0, 1582.5, 1822.5, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity70, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label=co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity load pattern where 70% user possess mixed time range but not Energy carrier', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 80% of users with mixed time range, 20% of user fixed time range and 100% of users allowed their appliances to operate on standard mode.

# %%
y_electricity80 = [1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 607.5, 13035.0, 6435.0, 607.5, 1635.0, 2835.0, 307.5, 13035.0, 13185.0, 15007.5, 11985.0, 8985.0, 5797.5, 1485.0, 1110.0, 3007.5, 4035.0, 4035.0, 2407.5, 2985.0, 2445.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1155.0, 4035.0, 127.5, 1155.0, 1155.0, 3007.5, 1485.0, 1260.0, 487.5, 13035.0, 1515.0, 487.5, 1515.0, 13035.0, 1807.5, 1935.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity80, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label=co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity load pattern where 80% user possess mixed time range but not Energy carrier', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 90% of users with mixed time range, 10% of user fixed time range and 100% of users allowed their appliances to operate on standard mode.

# %%
y_electricity90 = [1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 682.5, 14535.0, 7110.0, 682.5, 1710.0, 3060.0, 345.0, 14535.0, 14610.0, 15007.5, 12510.0, 9885.0, 6427.5, 1260.0, 1072.5, 1507.5, 2535.0, 2535.0, 1207.5, 2010.0, 1740.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1095.0, 2535.0, 67.5, 1095.0, 1095.0, 1507.5, 1260.0, 1147.5, 547.5, 14535.0, 1575.0, 547.5, 1575.0, 14535.0, 2032.5, 2047.5, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity90, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label=co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity load pattern where 90% user possess mixed time range but not Energy carrier', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.tight_layout()
plt.show()

# %% [markdown]
# # 100% of users with mixed time range and 100% of users allowed their appliances to operate on standard mode.

# %%
y_electricity100 = [1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 757.5, 16035.0, 7785.0, 757.5, 1785.0, 3285.0, 382.5, 16035.0, 16035.0, 15007.5, 13035.0, 10785.0, 7057.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 607.5, 16035.0, 1635.0, 607.5, 1635.0, 16035.0, 2257.5, 2160.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5, 1035.0, 1035.0, 7.5]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity100, color = 'b', label='Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15 Hours) to 96(6:00 Hours) Each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggregated electricity consumption in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label=co2)
ax2.set_ylabel('gCO2/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity load pattern where 100% user possess mixed time range but not Energy carrier', va='baseline', fontsize='15')
fig.legend(bbox_to_anchor=(0.1, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.text(0.3, 0.3, "OFF PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
fig.text(0.6, 0.95, "ON PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
fig.text(0.35, 0.7,"MID PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
fig.tight_layout()
plt.show()
