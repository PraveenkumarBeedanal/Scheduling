# %%
# Load pattern during more nonrenwebale energy production, where users allowed their appliance to operate on hybrid mode and mixed time range

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
SUB = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉")
co2 = "CO2".translate(SUB)

# %%
x = np.arange(1, 97, 1)

y_electricity = [1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1785,11910,757.5,1785,1785,2257.5,1410,2535,1507.5,2535,2535,1507.5,2535,2535,1507.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1635,7507.5,1635,1635,607.5,8535,1635,607.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5,1035,1035,7.5]

y_CO2_electricity  =[0.565, 0.56, 0.563, 0.563, 0.543, 0.555, 0.542, 0.542, 0.549, 0.545, 0.541, 0.533, 0.533, 0.53, 0.532, 0.527, 0.526, 0.525, 0.522, 0.52, 0.519, 0.519, 0.518, 0.517, 0.518, 0.519, 0.522, 0.527, 0.535, 0.538, 0.541, 0.545, 0.551, 0.556, 0.556, 0.564, 0.57, 0.572, 0.576, 0.578, 0.569, 0.564, 0.559, 0.553, 0.549, 0.55, 0.545, 0.561, 0.562, 0.565, 0.551, 0.567, 0.561, 0.567, 0.568, 0.571, 0.566, 0.57, 0.572, 0.57, 0.571, 0.572, 0.572, 0.571, 0.569, 0.569, 0.568, 0.568, 0.566, 0.563, 0.562, 0.563, 0.563, 0.563, 0.564, 0.563, 0.563, 0.564, 0.566, 0.568, 0.57, 0.572, 0.573, 0.574, 0.574, 0.578, 0.582, 0.585, 0.588, 0.591, 0.597, 0.602, 0.606, 0.610, 0.605, 0.603]

# %%
fig, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (10,8)
ax1.bar(x, y_electricity, color = 'b', label = 'Appliance Load')
ax1.set_xlabel('Time: Starting 1(06:15AM Hours) to 96(6:00AM Hours) each time slot=15 minutes', fontsize='15', color = 'b')
ax1.set_xticks(np.arange(0, 100, step=10))
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('aggrgated electricity consumption energy in Wh', fontsize='15', color = 'b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(x, y_CO2_electricity, 'r-', label = co2)
ax2.set_ylabel('g'+co2+'/Wh', fontsize='15', color = 'r')
ax2.tick_params('y', colors='r')

fig.suptitle('Electricity consumption of thirty users during large amount of non-renewable energy production', va='baseline', fontsize='15')
fig.tight_layout()
fig.legend(bbox_to_anchor=(0.12, 0.95), loc='upper left', borderaxespad=-0, prop={'size': 15})
fig.text(0.25, 0.2, "OFF PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
fig.text(0.8, 0.95, "ON PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
fig.text(0.35, 0.7,"MID PEAK", bbox=dict(facecolor='red', alpha=0.2), fontsize = 15)
plt.show()
